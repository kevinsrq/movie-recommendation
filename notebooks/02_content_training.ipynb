# %% [markdown]
# # Information retrieval for movies recommendation
#
# Database which the project it's based on:
# [HBO Max](https://www.kaggle.com/datasets/dgoenrique/hbo-max-movies-and-tv-shows)
#
# <div></div>

# %%
import numpy as np 
import pandas as pd
from toolbox import preprocessing
import ast

# %% [markdown]
# <div></div>
#
# ## Leitura dos Arquivos
#
# As bases vieram em formato CSV, portanto, só foi utilizado o pandas para leitura e feito um concat
#
# <div></div>

# %%
# load
try: 
    pop_movies = pd.read_csv('../data/modified/popular_movies.csv.zip')['tmdbId']
except: 
# Load the "rating" and "link" with the id from multiple sources
    ratings = pd.read_csv('../data/origin/ratings.zip')
    links = pd.read_csv('../data/origin/links.zip')

    # Inner join between both files
    ratings = ratings.merge(links, how='inner', on='movieId')

    # Select only the movies with at least 750 reviews, to classify as popular enough for recommendation
    pop_movies = ratings['movieId'].value_counts().to_frame().query('count > 250').index
    pop_movies = links.query('movieId in @pop_movies')['tmdbId'].dropna()

    pop_movies.to_csv('../data/modified/popular_movies.csv.zip', index=False, compression='zip')

    del ratings, links

# %%
# Load the 'credits' dataset from a zipped CSV file
dt_c = pd.read_csv('../data/origin/credits.zip')

# Load the 'movies_metadata' dataset from a zipped CSV file
dt_m = pd.read_csv('../data/origin/movies_metadata.zip')

# Convert the 'id' column to numeric data type, ignoring any errors
dt_m['id'] = pd.to_numeric(dt_m['id'], errors='coerce')

# Convert the 'popularity' column to numeric data type, ignoring any errors
dt_m['popularity'] = pd.to_numeric(dt_m['popularity'], errors='coerce')

# Merge the 'movies_metadata' DataFrame with the 'credits' DataFrame based on the 'id' column
dt_m = dt_m.merge(dt_c.set_index('id'), how='left', left_on=['id'], right_index=True)

# Drop rows with missing values in the 'id' column
dt_m.dropna(subset=['id', 'overview'], inplace=True)

# Select the movies with the minimun engagement
dt_m.query('id in @pop_movies', inplace=True)

# Reset index 
dt_m.reset_index(drop=True, inplace=True)

# Delete the 'credits' DataFrame to free up memory
del dt_c

dt_m.drop_duplicates(subset=['imdb_id'], inplace=True, ignore_index=True)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_13264\2466252914.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dt_m = pd.read_csv('../data/origin/movies_metadata.zip')

# %%
# Define the variables
v = 'vote_count'  # Vote count column
m = 'vote_count.quantile(0.85)'  # Quantile of vote count
R = 'vote_average'  # Vote average column
C = 'vote_average.mean()'  # Mean of vote average

# Evaluate the score using the defined variables and assign it to a new column 'score'
dt_m.eval(f'score = ({v}/({v}+{m}) * {R}) + ({m}/({m}+{v}) * {C})', inplace=True)

del v, m, R, C

# %% [markdown]
# <div></div>
#
# ## Pré-Processamento de Texto
#
# <div></div>

# %% [markdown]
# ### Remoção de palavras e transformação de minúsculos

# %%
# Removing special characters and numbers from the 'overview' column
dt_m['p_overview'] = dt_m['overview'].replace(r'([^\w\s]|\d+)', ' ', regex=True)
# Applying lowercase and strip simultaneously to the 'p_overview' column
dt_m['p_overview'] = dt_m['p_overview'].apply(lambda x: x.lower().strip() if isinstance(x, str) else x)
# Extracting lowercase genre names from the 'genres' column and replacing spaces with underscores
dt_m['p_genres'] = dt_m['genres'].map(lambda genres: [genre.get('name').lower().replace(' ', '_') for genre in ast.literal_eval(genres)])

# Removing stopwords from the 'p_overview' column
dt_m['p_overview'] = dt_m['p_overview'].map(preprocessing.remove_stopwords)
# Lemmatizing the text in the 'p_overview' column
dt_m['p_overview'] = dt_m['p_overview'].map(preprocessing.lemmatize_text)
# Tokenizing the words in the 'p_overview' column
dt_m['p_overview'] = dt_m['p_overview'].map(preprocessing.word_tokenize)

# Filtering out rows where 'p_overview' has a length greater than 0
dt_m.query('p_overview.str.len() > 0', inplace=True)
# Checking the shape of the DataFrame after filtering rows where 'p_genres' has a length greater than 0
dt_m.query('p_genres.str.len() > 0', inplace=True)

# Resetting the index of the DataFrame to ensure it starts from 0
dt_m.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### TF-IDF from Corpus

# %%
from gensim import corpora
from gensim import models
import numpy as np

data = dt_m['p_overview'].to_list()

# Create a dictionary based on the 'p_overview' data
dictionary = corpora.Dictionary(data)

# Convert the data into Bag of Words (BoW) representation
bow_corpus = [dictionary.doc2bow(doc, allow_update=True) for doc in data]

# Word weight in Bag of Words corpus
word_weight = []

# Iterate over each document in the BoW corpus
for doc in bow_corpus:
    # Extract the word ID and frequency for each word in the document
    for id, freq in doc:
        word_weight.append([dictionary[id], freq])

# Create a TF-IDF model based on the BoW corpus
tfIdf = models.TfidfModel(bow_corpus, smartirs='nfc')

# TF-IDF Word Weight
weight_tfidf = []
# Iterate over each document in the TF-IDF representation
for doc in tfIdf[bow_corpus]:
    # Extract the word ID and TF-IDF weight for each word in the document
    for id, freq in doc:
        weight_tfidf.append([dictionary[id], np.around(freq, decimals=3)])

# Identify words to remove based on their TF-IDF weight
remove = pd.Series([x[0] for x in weight_tfidf if x[1] <= 0.04]).unique()
remove = set(remove)

# Filter out the words to be removed from the 'p_overview' column of dt_m
dt_m['p_overview'] = dt_m['p_overview'].map(lambda words: [x for x in words if x not in remove])

# %% [markdown]
# # Using a Model for Information Retrieval
#
# ## Similarity by description

# %%
from gensim.models import KeyedVectors

# Load pre-trained word vectors using Word2Vec format
model = KeyedVectors.load_word2vec_format('../models/numberbatch-en.txt')

# Create a set of vocabulary words from the loaded model
index_set = set(model.index_to_key)

# Filter out words in 'p_overview' that are not present in the vocabulary set
dt_m['p_overview'] = dt_m['p_overview'].map(lambda words: [w for w in words if w in index_set])

# %%
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel

query = dt_m['p_overview'][0]

query_vector = sum(model[word] for word in query) / len(query)

dt_m['embed_docs'] = dt_m['p_overview'].map(lambda doc: sum(model[word] for word in doc) / len(doc))

similarities = dt_m['embed_docs'].map(lambda doc: cosine_similarity(query_vector.reshape(1, -1) , doc.reshape(1, -1))).sort_values(ascending=False)[:100]

sim = {i: v[0][0] for i, v in zip(similarities.index, similarities.values)}

# %%
dt_m.iloc[list(sim.keys()),:].sort_values(by=['score', 'popularity'], ascending=False)[:10]
# Out:
#       adult                              belongs_to_collection     budget
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000  \
# 6128  False  {'id': 10194, 'name': 'Toy Story Collection', ...  200000000
# 2325  False  {'id': 10194, 'name': 'Toy Story Collection', ...   90000000
# 5931  False                                                NaN    7500000
# 2226  False                                                NaN   70000000
# 845   False                                                NaN    1500000
# 1459  False  {'id': 10453, 'name': 'Poltergeist Collection'...   10700000
# 692   False                                                NaN     325000
# 3496  False                                                NaN   22000000
# 2555  False                                                NaN   30000000
#
#                                                  genres
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 6128  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2325  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 5931  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2226  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 845                       [{'id': 18, 'name': 'Drama'}]
# 1459                     [{'id': 27, 'name': 'Horror'}]
# 692   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3496                      [{'id': 18, 'name': 'Drama'}]
# 2555  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                     homepage       id    imdb_id
# 0       http://toystory.disney.com/toy-story    862.0  tt0114709  \
# 6128          http://disney.go.com/toystory/  10193.0  tt0435761
# 2325  http://toystory.disney.com/toy-story-2    863.0  tt0120363
# 5931                      http://500days.com  19913.0  tt1022603
# 2226                                     NaN    856.0  tt0096438
# 845                                      NaN    221.0  tt0048545
# 1459                                     NaN    609.0  tt0084516
# 692                                      NaN   3078.0  tt0025316
# 3496                                     NaN  10950.0  tt0277027
# 2555                                     NaN    243.0  tt0146882
#
#      original_language           original_title
# 0                   en                Toy Story  \
# 6128                en              Toy Story 3
# 2325                en              Toy Story 2
# 5931                en     (500) Days of Summer
# 2226                en  Who Framed Roger Rabbit
# 845                 en    Rebel Without a Cause
# 1459                en              Poltergeist
# 692                 en    It Happened One Night
# 3496                en                 I Am Sam
# 2555                en            High Fidelity
#
#                                                overview  ...
# 0     Led by Woody, Andy's toys live happily in his ...  ...  \
# 6128  Woody, Buzz, and the rest of Andy's toys haven...  ...
# 2325  Andy heads off to Cowboy Camp, leaving his toy...  ...
# 5931  Tom (Joseph Gordon-Levitt), greeting-card writ...  ...
# 2226  'Toon star Roger is worried that his wife Jess...  ...
# 845   After moving to a new town, troublemaking teen...  ...
# 1459  Steve Freeling lives with his wife, Diane, and...  ...
# 692   Ellie Andrews has just tied the knot with soci...  ...
# 3496  Sam has the mental capacity of a 7-year-old. H...  ...
# 2555  When record store owner Rob Gordon gets dumped...  ...
#
#                         title  video vote_average vote_count
# 0                   Toy Story  False          7.7     5415.0  \
# 6128              Toy Story 3  False          7.6     4710.0
# 2325              Toy Story 2  False          7.3     3914.0
# 5931     (500) Days of Summer  False          7.2     2993.0
# 2226  Who Framed Roger Rabbit  False          7.2     1466.0
# 845     Rebel Without a Cause  False          7.6      351.0
# 1459              Poltergeist  False          7.1      811.0
# 692     It Happened One Night  False          7.7      283.0
# 3496                 I Am Sam  False          7.2      542.0
# 2555            High Fidelity  False          7.0      636.0
#
#                                                    cast
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 6128  [{'cast_id': 6, 'character': 'Woody (voice)', ...
# 2325  [{'cast_id': 18, 'character': 'Woody (voice)',...
# 5931  [{'cast_id': 4, 'character': 'Tom Hansen', 'cr...
# 2226  [{'cast_id': 17, 'character': 'Eddie Valiant',...
# 845   [{'cast_id': 6, 'character': 'Jim Stark', 'cre...
# 1459  [{'cast_id': 21, 'character': 'Steve Freeling'...
# 692   [{'cast_id': 10, 'character': 'Peter Warne', '...
# 3496  [{'cast_id': 1, 'character': 'Sam Dawson', 'cr...
# 2555  [{'cast_id': 7, 'character': 'Rob Gordon', 'cr...
#
#                                                    crew     score
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  7.500085  \
# 6128  [{'credit_id': '5770143fc3a3683733000f3a', 'de...  7.393455
# 2325  [{'credit_id': '52fe4284c3a36847f8025073', 'de...  7.122641
# 5931  [{'credit_id': '52fe47f99251416c750abaa5', 'de...  7.007609
# 2226  [{'credit_id': '52fe4282c3a36847f80249a9', 'de...  6.889856
# 845   [{'credit_id': '52fe4228c3a36847f8008749', 'de...  6.740996
# 1459  [{'credit_id': '52fe425dc3a36847f8018967', 'de...  6.735367
# 692   [{'credit_id': '52fe4383c3a36847f8059c33', 'de...  6.718043
# 3496  [{'credit_id': '52fe43d89251416c7502045d', 'de...  6.707429
# 2555  [{'credit_id': '52fe422cc3a36847f8009919', 'de...  6.658839
#
#                                              p_overview
# 0     [led, woody, andy, toys, happily, room, until,...  \
# 6128  [woody, buzz, rest, andy, toys, haven, played,...
# 2325  [andy, heads, cowboy, camp, leaving, toys, dev...
# 5931  [tom, joseph, gordon, levitt, greeting, card, ...
# 2226  [toon, star, roger, worried, jessica, playing,...
# 845   [moving, town, troublemaking, teen, jim, stark...
# 1459  [steve, diane, children, dana, robbie, carol, ...
# 692   [ellie, andrews, tied, knot, society, aviator,...
# 3496  [sam, mental, capacity, homeless, abandons, le...
# 2555  [record, store, owner, rob, gordon, dumped, gi...
#
#                                          p_genres
# 0                     [animation, comedy, family]  \
# 6128                  [animation, family, comedy]
# 2325                  [animation, comedy, family]
# 5931                     [comedy, drama, romance]
# 2226  [fantasy, animation, comedy, crime, family]
# 845                                       [drama]
# 1459                                     [horror]
# 692                             [comedy, romance]
# 3496                                      [drama]
# 2555              [comedy, drama, romance, music]
#
#                                              embed_docs
# 0     [-0.066558816, -0.06601177, 0.03052059, 0.0370...
# 6128  [-0.05681363, -0.065113634, 0.039022733, 0.052...
# 2325  [-0.053141665, -0.04976667, 0.03131111, 0.0481...
# 5931  [-0.059767745, -0.083354846, 0.019109681, -0.0...
# 2226  [-0.04540769, -0.07091923, 0.020792305, 0.0202...
# 845   [-0.05226364, -0.07014319, 0.0114068175, 0.007...
# 1459  [-0.037136108, -0.06258333, 0.015158336, 0.033...
# 692   [-0.047841664, -0.07986041, 0.03252917, 0.0334...
# 3496  [-0.06321563, -0.06864375, -0.0142250005, 0.02...
# 2555  [-0.060336668, -0.08761667, -0.0049099987, 0.0...
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Similarity by genres

# %%
dt_m['embed_genres'] = dt_m['p_genres'].map(lambda doc: sum(model[word] for word in doc) / len(doc))

# %% [markdown]
# ## Similarity by Cast

# %%
a = ast.literal_eval(dt_m['crew'][0])

# %%
[x.get('name').lower().replace(' ', '_') for x in a if x.get('job').lower()=='director']
# Out:
# ['john_lasseter']

# %%
def get_director(crew):

# %%
dt_m['director'] = dt_m['crew'].map(lambda crew: [x.get('name').lower().replace(' ', '_') for x in ast.literal_eval(crew) if x.get('job').lower()=='director'])

# %%
dt_m['director'][7106]
# Out:
# ['tom_hanks',
#  'david_frankel',
#  'phil_alden_robinson',
#  'mikael_salomon',
#  'richard_loncraine',
#  'david_nutter',
#  'david_leland',
#  'tony_to']

# %%
dt_m['director'][0][0]
# Out:
# 'john_lasseter'

# %%
dt_m['director'].map(lambda dir: ast.List(dir))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 dt_m['director'].map(lambda dir: ast.List(dir)[0])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4393, in Series.map(self, arg, na_action)
#    4314 def map(
#    4315     self,
#    4316     arg: Callable | Mapping | Series,
#    4317     na_action: Literal["ignore"] | None = None,
#    4318 ) -> Series:
#    4319     """
#    4320     Map values of Series according to an input mapping or function.
#    4321
#    (...)
#    4391     dtype: object
#    4392     """
# -> 4393     new_values = self._map_values(arg, na_action=na_action)
#    4394     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4395         self, method="map"
#    4396     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[99], line 1, in <lambda>(dir)
# ----> 1 dt_m['director'].map(lambda dir: ast.List(dir)[0])
#
# TypeError: 'List' object is not subscriptable

# %%
[x.get('name').lower().replace(' ', '_') for x in a if x.get('job').lower()=='director']
# Out:
# ['John Lasseter']

# %%
def find_similar(title, embed_model, database:pd.DataFrame = dt_m): 
    
    movie_data = database.query(f"title=='{title}'")
    
    # only search for movies in the same genre
    mask = database['p_genres'].map(lambda genres: any(set(genres).intersection(movie_data['p_genres'][0])))

    database.query('@mask', inplace=True)

    embed_query = sum(model[word] for word in movie_data['p_overview'])[0] / len(movie_data['p_overview'][0])

    ov_similarity = database['embed_docs'].map(lambda doc: cosine_similarity(embed_query.reshape(1, -1) , doc.reshape(1, -1))).sort_values(ascending=False)[:500]
    
    ov_similarity = {i: j[0][0] for i, j in zip(ov_similarity.index, ov_similarity.values)}

    return database.query('@ov_similarity.keys()').sort_values(by='score')


find_similar('Toy Story', embed_model=model)
# Out:
#       adult                              belongs_to_collection     budget
# 5415  False                                                NaN   20000000  \
# 5386  False                                                NaN  100000000
# 6931  False                                                NaN   88000000
# 4070  False  {'id': 86029, 'name': "Charlie's Angels Collec...  120000000
# 6632  False                                                NaN  130000000
# ...     ...                                                ...        ...
# 607   False                                                NaN    1800000
# 6128  False  {'id': 10194, 'name': 'Toy Story Collection', ...  200000000
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 5707  False                                                NaN  180000000
# 3758  False                                                NaN   15000000
#
#                                                  genres
# 5415  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  \
# 5386  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
# 6931  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 4070  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6632  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
# ...                                                 ...
# 607   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 6128  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 5707  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3758  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
#
#                                          homepage        id    imdb_id
# 5415                                          NaN    9760.0  tt0799949  \
# 5386                  http://www.eragonmovie.com/    2486.0  tt0449010
# 6931                 http://www.pixels-movie.com/  257344.0  tt2120120
# 4070                                          NaN    9471.0  tt0305357
# 6632                         http://www.ripd.com/   49524.0  tt0790736
# ...                                           ...       ...        ...
# 607                                           NaN     935.0  tt0057012
# 6128               http://disney.go.com/toystory/   10193.0  tt0435761
# 0            http://toystory.disney.com/toy-story     862.0  tt0114709
# 5707  http://disney.go.com/disneypictures/wall-e/   10681.0  tt0910970
# 3758       http://movies.disney.com/spirited-away     129.0  tt0245429
#
#      original_language                                     original_title
# 5415                en                                         Epic Movie  \
# 5386                en                                             Eragon
# 6931                en                                             Pixels
# 4070                en                    Charlie's Angels: Full Throttle
# 6632                en                                           R.I.P.D.
# ...                ...                                                ...
# 607                 en  Dr. Strangelove or: How I Learned to Stop Worr...
# 6128                en                                        Toy Story 3
# 0                   en                                          Toy Story
# 5707                en                                             WALL·E
# 3758                ja                                           千と千尋の神隠し
#
#                                                overview  ...  video
# 5415  When Edward, Peter, Lucy and Susan each follow...  ...  False  \
# 5386  In his homeland of Alagaesia, a farm boy happe...  ...  False
# 6931  Video game experts are recruited by the milita...  ...  False
# 4070  The Angels are charged with finding a pair of ...  ...  False
# 6632  A recently slain cop joins a team of undead po...  ...  False
# ...                                                 ...  ...    ...
# 607   Insane General Jack D. Ripper initiates a nucl...  ...  False
# 6128  Woody, Buzz, and the rest of Andy's toys haven...  ...  False
# 0     Led by Woody, Andy's toys live happily in his ...  ...  False
# 5707  WALL·E is the last robot left on an Earth that...  ...  False
# 3758  A ten year old girl who wanders away from her ...  ...  False
#
#      vote_average vote_count
# 5415          3.2      334.0  \
# 5386          4.9      990.0
# 6931          5.6     2564.0
# 4070          5.2      930.0
# 6632          5.4     1280.0
# ...           ...        ...
# 607           8.0     1472.0
# 6128          7.6     4710.0
# 0             7.7     5415.0
# 5707          7.8     6439.0
# 3758          8.3     3968.0
#
#                                                    cast
# 5415  [{'cast_id': 1, 'character': 'Edward', 'credit...  \
# 5386  [{'cast_id': 1, 'character': 'Eragon', 'credit...
# 6931  [{'cast_id': 17, 'character': 'Sam Brenner', '...
# 4070  [{'cast_id': 1, 'character': 'Natalie Cook', '...
# 6632  [{'cast_id': 3, 'character': 'Roy Pulsipher', ...
# ...                                                 ...
# 607   [{'cast_id': 13, 'character': 'Group Capt. Lio...
# 6128  [{'cast_id': 6, 'character': 'Woody (voice)', ...
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 5707  [{'cast_id': 12, 'character': 'WALL·E / M-O (v...
# 3758  [{'cast_id': 3, 'character': 'Chihiro Ogino (v...
#
#                                                    crew     score
# 5415  [{'credit_id': '56348a269251412857016e9e', 'de...  5.651993  \
# 5386  [{'credit_id': '52fe435ac3a36847f804de45', 'de...  5.688890
# 6931  [{'credit_id': '530f7120c3a36874ca001178', 'de...  5.842829
# 4070  [{'credit_id': '52fe44fbc3a36847f80b5bd7', 'de...  5.855481
# 6632  [{'credit_id': '570b93599251412c740021f0', 'de...  5.866993
# ...                                                 ...       ...
# 607   [{'credit_id': '52fe4290c3a36847f802876d', 'de...  7.361470
# 6128  [{'credit_id': '5770143fc3a3683733000f3a', 'de...  7.393455
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  7.500085
# 5707  [{'credit_id': '52fe43a29251416c75018101', 'de...  7.613720
# 3758  [{'credit_id': '52fe421bc3a36847f8004a8d', 'de...  7.918650
#
#                                              p_overview
# 5415  [edward, peter, lucy, susan, follow, path, fin...  \
# 5386  [homeland, farm, happens, upon, dragon, egg, d...
# 6931  [video, game, experts, recruited, military, er...
# 4070  [angels, charged, finding, pair, missing, ring...
# 6632  [recently, slain, cop, joins, team, undead, po...
# ...                                                 ...
# 607   [insane, general, jack, d, ripper, initiates, ...
# 6128  [woody, buzz, rest, andy, toys, haven, played,...
# 0     [led, woody, andy, toys, happily, room, until,...
# 5707  [wall, e, last, robot, left, earth, overrun, g...
# 3758  [ten, girl, wanders, away, parents, along, pat...
#
#                                      p_genres
# 5415              [action, adventure, comedy]  \
# 5386     [fantasy, action, adventure, family]
# 6931        [action, comedy, science_fiction]
# 4070              [action, adventure, comedy]
# 6632         [fantasy, action, comedy, crime]
# ...                                       ...
# 607                      [drama, comedy, war]
# 6128              [animation, family, comedy]
# 0                 [animation, comedy, family]
# 5707                      [animation, family]
# 3758  [fantasy, adventure, animation, family]
#
#                                              embed_docs
# 5415  [-0.02639697, -0.05262121, 0.050836366, 0.0097...  \
# 5386  [-0.050307143, -0.06353571, -0.0042571416, 0.0...
# 6931  [-0.040050004, -0.0658, -0.042683333, 0.056441...
# 4070  [-0.07086666, -0.045490474, -0.050476193, 0.04...
# 6632  [-0.028838893, -0.07171667, -0.022555554, 0.03...
# ...                                                 ...
# 607   [-0.046969235, -0.056956418, -0.030351281, 0.0...
# 6128  [-0.05681363, -0.065113634, 0.039022733, 0.052...
# 0     [-0.066558816, -0.06601177, 0.03052059, 0.0370...
# 5707  [-0.06863334, -0.03866945, 0.01928611, 0.05068...
# 3758  [-0.054411996, -0.053764, 0.035356, 0.010176, ...
#
#                                            embed_genres
# 5415  [-0.064166665, -0.0864, -0.0491, -0.0034999996...
# 5386  [-0.048224997, -0.060825, -0.018399999, -0.005...
# 6931  [-0.07173333, -0.040599998, -0.0806, -0.018666...
# 4070  [-0.064166665, -0.0864, -0.0491, -0.0034999996...
# 6632  [-0.0736, -0.079375, -0.05555, -0.030749999, -...
# ...                                                 ...
# 607   [-0.035833333, -0.09153333, -0.042766664, -0.0...
# 6128  [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 0     [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 5707  [-0.014, 0.01655, -0.017599998, -0.01735, -0.1...
# 3758  [-0.027174998, -0.029850002, -0.0017499989, -0...
#
# [500 rows x 31 columns]

# %%
# Out:
#       adult                              belongs_to_collection     budget
# 6128  False  {'id': 10194, 'name': 'Toy Story Collection', ...  200000000  \
# 2325  False  {'id': 10194, 'name': 'Toy Story Collection', ...   90000000
# 1346  False                                                NaN          0
# 237   False                                                NaN          0
# 2455  False                                                NaN   25000000
# 2080  False                                                NaN          0
# 5087  False                                                NaN   26000000
# 3602  False                                                NaN   43000000
# 5148  False  {'id': 298820, 'name': 'American Pie (Spin-off...   10000000
#
#                                                  genres
# 6128  [{'id': 16, 'name': 'Animation'}, {'id': 10751...  \
# 2325  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1346  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 237   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2455                     [{'id': 35, 'name': 'Comedy'}]
# 2080  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 5087  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3602  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 5148                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                homepage       id    imdb_id
# 6128                     http://disney.go.com/toystory/  10193.0  tt0435761  \
# 2325             http://toystory.disney.com/toy-story-2    863.0  tt0120363
# 1346                                                NaN  15513.0  tt0120723
# 237                                                 NaN  40490.0  tt0113755
# 2455                                                NaN   1831.0  tt0156841
# 2080                                                NaN  10552.0  tt0088889
# 5087  http://www.universalstudiosentertainment.com/t...   6957.0  tt0405422
# 3602  http://www.sonypictures.com/movies/thesweetest...  11812.0  tt0253867
# 5148               http://www.americanreunionmovie.com/   8274.0  tt0436058
#
#      original_language                    original_title
# 6128                en                       Toy Story 3  \
# 2325                en                       Toy Story 2
# 1346                en                    Kissing a Fool
# 237                 en                  Man of the House
# 2455                en               The Next Best Thing
# 2080                en                         Cat's Eye
# 5087                en            The 40 Year Old Virgin
# 3602                en                The Sweetest Thing
# 5148                en  American Pie Presents: Band Camp
#
#                                                overview  ...  video
# 6128  Woody, Buzz, and the rest of Andy's toys haven...  ...  False  \
# 2325  Andy heads off to Cowboy Camp, leaving his toy...  ...  False
# 1346  Max (David Schwimmer), an alpha-male commitmen...  ...  False
# 237   Ben Archer is not happy. His mother, Sandy, ha...  ...  False
# 2455  A comedy-drama about best friends - one a stra...  ...  False
# 2080  Three short stories by shock-meister Stephen K...  ...  False
# 5087  Andy Stitzer has a pleasant life with a nice a...  ...  False
# 3602  Christina's love life is stuck in neutral. Aft...  ...  False
# 5148  The original American Pie characters have move...  ...  False
#
#      vote_average vote_count
# 6128          7.6     4710.0  \
# 2325          7.3     3914.0
# 1346          5.9       16.0
# 237           5.1       40.0
# 2455          4.3       29.0
# 2080          5.9      140.0
# 5087          6.2     2020.0
# 3602          5.3      286.0
# 5148          5.3      553.0
#
#                                                    cast
# 6128  [{'cast_id': 6, 'character': 'Woody (voice)', ...  \
# 2325  [{'cast_id': 18, 'character': 'Woody (voice)',...
# 1346  [{'cast_id': 1, 'character': 'Max Abbitt', 'cr...
# 237   [{'cast_id': 2, 'character': 'Sandy Archer', '...
# 2455  [{'cast_id': 3, 'character': 'Abbie Reynolds',...
# 2080  [{'cast_id': 1, 'character': 'Amanda', 'credit...
# 5087  [{'cast_id': 1, 'character': 'Andy Stitzer', '...
# 3602  [{'cast_id': 10, 'character': 'Christina Walte...
# 5148  [{'cast_id': 7, 'character': 'Mr. Levenstein',...
#
#                                                    crew     score
# 6128  [{'credit_id': '5770143fc3a3683733000f3a', 'de...  7.393455  \
# 2325  [{'credit_id': '52fe4284c3a36847f8025073', 'de...  7.122641
# 1346  [{'credit_id': '52fe46639251416c75076af5', 'de...  6.439564
# 237   [{'credit_id': '52fe4594c3a36847f80cf2d7', 'de...  6.397512
# 2455  [{'credit_id': '52fe4318c3a36847f8039dff', 'de...  6.389074
# 2080  [{'credit_id': '52fe43869251416c75013d3d', 'de...  6.382326
# 5087  [{'credit_id': '52fe446ac3a36847f8094c49', 'de...  6.283676
# 3602  [{'credit_id': '52fe448a9251416c75038579', 'de...  6.198267
# 5148  [{'credit_id': '52fe449ac3a36847f809f9f7', 'de...  6.046653
#
#                                              p_overview
# 6128  [woody, buzz, rest, andy, toys, haven, played,...  \
# 2325  [andy, heads, cowboy, camp, leaving, toys, dev...
# 1346  [max, david, schwimmer, alpha, male, commitmen...
# 237   [ben, archer, happy, sandy, met, looks, things...
# 2455  [comedy, drama, straight, abbie, gay, robert, ...
# 2080  [short, stories, shock, meister, stephen, king...
# 5087  [andy, pleasant, nice, apartment, job, stampin...
# 3602  [christina, stuck, neutral, avoiding, hazards,...
# 5148  [original, american, pie, characters, moved, e...
#
#                          p_genres
# 6128  [animation, family, comedy]  \
# 2325  [animation, comedy, family]
# 1346            [comedy, romance]
# 237      [action, comedy, family]
# 2455                     [comedy]
# 2080   [comedy, thriller, horror]
# 5087            [comedy, romance]
# 3602            [romance, comedy]
# 5148                     [comedy]
#
#                                              embed_docs
# 6128  [-0.05681363, -0.065113634, 0.039022733, 0.052...  \
# 2325  [-0.053141665, -0.04976667, 0.03131111, 0.0481...
# 1346  [-0.05744562, -0.06525087, -0.01512807, 0.0165...
# 237   [-0.066242866, -0.08415, 0.024992859, 0.000971...
# 2455  [-0.04997826, -0.08250869, 0.01794348, 0.01859...
# 2080  [-0.052583344, -0.06680237, 0.027269045, 0.010...
# 5087  [-0.057471428, -0.0701619, 0.0024571428, 0.028...
# 3602  [-0.05996875, -0.07875626, 0.0074375, 0.040274...
# 5148  [-0.055151217, -0.075946346, 0.029085366, 0.02...
#
#                                            embed_genres
# 6128  [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 2325  [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 1346  [0.0026000002, -0.069800004, -0.0206, -0.1107,...
# 237   [-0.045366663, -0.052233335, -0.039633334, -0....
# 2455  [-0.0239, -0.0659, -0.0171, -0.0843, -0.0926, ...
# 2080  [-0.044033334, -0.0675, 0.004166667, -0.105433...
# 5087  [0.0026000002, -0.069800004, -0.0206, -0.1107,...
# 3602  [0.0026000002, -0.069800004, -0.0206, -0.1107,...
# 5148  [-0.0239, -0.0659, -0.0171, -0.0843, -0.0926, ...
#
# [9 rows x 31 columns]

# %%
dt_m.query('@s')
# Out:
#       adult                              belongs_to_collection     budget
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000  \
# 6128  False  {'id': 10194, 'name': 'Toy Story Collection', ...  200000000
# 2325  False  {'id': 10194, 'name': 'Toy Story Collection', ...   90000000
# 5148  False  {'id': 298820, 'name': 'American Pie (Spin-off...   10000000
# 5087  False                                                NaN   26000000
# ...     ...                                                ...        ...
# 2601  False                                                NaN          0
# 4764  False                                                NaN          0
# 2373  False                                                NaN    7000000
# 6248  False  {'id': 9888, 'name': 'Home Alone Collection', ...          0
# 6332  False                                                NaN   50000000
#
#                                                  genres
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 6128  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2325  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 5148                     [{'id': 35, 'name': 'Comedy'}]
# 5087  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...                                                 ...
# 2601  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4764  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2373  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 6248  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 6332  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                                homepage       id    imdb_id
# 0                  http://toystory.disney.com/toy-story    862.0  tt0114709  \
# 6128                     http://disney.go.com/toystory/  10193.0  tt0435761
# 2325             http://toystory.disney.com/toy-story-2    863.0  tt0120363
# 5148               http://www.americanreunionmovie.com/   8274.0  tt0436058
# 5087  http://www.universalstudiosentertainment.com/t...   6957.0  tt0405422
# ...                                                 ...      ...        ...
# 2601                                                NaN  16347.0  tt0051383
# 4764                                                NaN  18701.0  tt0340012
# 2373                   http://mydogskip.warnerbros.com/  17908.0  tt0156812
# 6248                                                NaN  12536.0  tt0329200
# 6332   http://crazystupidlove.warnerbros.com/index.html  50646.0  tt1570728
#
#      original_language                    original_title
# 0                   en                         Toy Story  \
# 6128                en                       Toy Story 3
# 2325                en                       Toy Story 2
# 5148                en  American Pie Presents: Band Camp
# 5087                en            The 40 Year Old Virgin
# ...                ...                               ...
# 2601                en                       Auntie Mame
# 4764                en                       Being Julia
# 2373                en                       My Dog Skip
# 6248                en                      Home Alone 4
# 6332                en              Crazy, Stupid, Love.
#
#                                                overview  ...  video
# 0     Led by Woody, Andy's toys live happily in his ...  ...  False  \
# 6128  Woody, Buzz, and the rest of Andy's toys haven...  ...  False
# 2325  Andy heads off to Cowboy Camp, leaving his toy...  ...  False
# 5148  The original American Pie characters have move...  ...  False
# 5087  Andy Stitzer has a pleasant life with a nice a...  ...  False
# ...                                                 ...  ...    ...
# 2601  Ten-year-old orphan Patrick Dennis has come to...  ...  False
# 4764  Julia Lambert is a true diva: beautiful, talen...  ...  False
# 2373  A shy boy is unable to make friends in Yazoo C...  ...  False
# 6248  Kevin McCallister's parents have split up. Now...  ...  False
# 6332  Cal Weaver is living the American dream. He ha...  ...  False
#
#      vote_average vote_count
# 0             7.7     5415.0  \
# 6128          7.6     4710.0
# 2325          7.3     3914.0
# 5148          5.3      553.0
# 5087          6.2     2020.0
# ...           ...        ...
# 2601          6.4       28.0
# 4764          6.4       23.0
# 2373          6.5       71.0
# 6248          3.9      239.0
# 6332          7.0     2522.0
#
#                                                    cast
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 6128  [{'cast_id': 6, 'character': 'Woody (voice)', ...
# 2325  [{'cast_id': 18, 'character': 'Woody (voice)',...
# 5148  [{'cast_id': 7, 'character': 'Mr. Levenstein',...
# 5087  [{'cast_id': 1, 'character': 'Andy Stitzer', '...
# ...                                                 ...
# 2601  [{'cast_id': 20, 'character': 'Mame Dennis', '...
# 4764  [{'cast_id': 1, 'character': 'Jimmie Langton',...
# 2373  [{'cast_id': 1, 'character': 'Willie Morris', ...
# 6248  [{'cast_id': 1, 'character': 'Marv Merchants',...
# 6332  [{'cast_id': 3, 'character': 'Cal Weaver', 'cr...
#
#                                                    crew     score
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  7.500085  \
# 6128  [{'credit_id': '5770143fc3a3683733000f3a', 'de...  7.393455
# 2325  [{'credit_id': '52fe4284c3a36847f8025073', 'de...  7.122641
# 5148  [{'credit_id': '52fe449ac3a36847f809f9f7', 'de...  6.046653
# 5087  [{'credit_id': '52fe446ac3a36847f8094c49', 'de...  6.283676
# ...                                                 ...       ...
# 2601  [{'credit_id': '52fe46c89251416c750836ab', 'de...  6.446685
# 4764  [{'credit_id': '52fe47929251416c7509e4a3', 'de...  6.446906
# 2373  [{'credit_id': '52fe47519251416c750951a5', 'de...  6.451315
# 6248  [{'credit_id': '52fe44f69251416c75046f77', 'de...  5.967664
# 6332  [{'credit_id': '565b6197c3a368507d0034b0', 'de...  6.840041
#
#                                              p_overview
# 0     [led, woody, andy, toys, happily, room, until,...  \
# 6128  [woody, buzz, rest, andy, toys, haven, played,...
# 2325  [andy, heads, cowboy, camp, leaving, toys, dev...
# 5148  [original, american, pie, characters, moved, e...
# 5087  [andy, pleasant, nice, apartment, job, stampin...
# ...                                                 ...
# 2601  [ten, orphan, patrick, dennis, come, nearest, ...
# 4764  [julia, lambert, true, diva, beautiful, talent...
# 2373  [shy, unable, make, yazoo, city, mississippi, ...
# 6248  [kevin, mccallister, parents, split, living, m...
# 6332  [cal, weaver, living, american, dream, good, j...
#
#                          p_genres
# 0     [animation, comedy, family]  \
# 6128  [animation, family, comedy]
# 2325  [animation, comedy, family]
# 5148                     [comedy]
# 5087            [comedy, romance]
# ...                           ...
# 2601              [comedy, drama]
# 4764     [comedy, drama, romance]
# 2373      [comedy, drama, family]
# 6248      [crime, comedy, family]
# 6332     [comedy, drama, romance]
#
#                                              embed_docs
# 0     [-0.066558816, -0.06601177, 0.03052059, 0.0370...  \
# 6128  [-0.05681363, -0.065113634, 0.039022733, 0.052...
# 2325  [-0.053141665, -0.04976667, 0.03131111, 0.0481...
# 5148  [-0.055151217, -0.075946346, 0.029085366, 0.02...
# 5087  [-0.057471428, -0.0701619, 0.0024571428, 0.028...
# ...                                                 ...
# 2601  [-0.038778257, -0.06975654, 0.01971884, 0.0029...
# 4764  [-0.07180445, -0.07688001, 0.019824447, -0.004...
# 2373  [-0.02927188, -0.06497812, 0.023803126, 0.0190...
# 6248  [-0.013316001, -0.065524, 0.026904006, 0.00622...
# 6332  [-0.048736587, -0.06731708, 0.009102439, 0.006...
#
#                                            embed_genres
# 0     [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 6128  [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 2325  [-0.0173, -0.010933332, -0.017433332, -0.03966...
# 5148  [-0.0239, -0.0659, -0.0171, -0.0843, -0.0926, ...
# 5087  [0.0026000002, -0.069800004, -0.0206, -0.1107,...
# ...                                                 ...
# 2601  [-0.04195, -0.078999996, -0.03995, -0.0787, -0...
# 4764  [-0.018266665, -0.07723334, -0.034666665, -0.0...
# 2373  [-0.017033333, -0.04803333, -0.015099999, -0.0...
# 6248  [-0.019833336, -0.045, -0.024400001, -0.057066...
# 6332  [-0.018266665, -0.07723334, -0.034666665, -0.0...
#
# [500 rows x 31 columns]

# %%
similarities = cosine_similarity(query_vector.reshape(1, -1), document_vectors[10].reshape(1, -1))

# %%
# Calculate cosine similarity between query vector and document vectors
similarities = cosine_similarity(query_vector.reshape(1, -1), document_vectors)

# Get the indices of the most similar documents
most_similar_indices = similarities.argsort()[0][::-1]

# Retrieve the most similar documents
most_similar_documents = [corpus[i] for i in most_similar_indices]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Calculate cosine similarity between query vector and document vectors
# ----> 2 similarities = cosine_similarity(query_vector.reshape(1, -1), document_vectors)
#       4 # Get the indices of the most similar documents
#       5 most_similar_indices = similarities.argsort()[0][::-1]
#
# NameError: name 'document_vectors' is not defined
